# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Launch Sites Locations Analysis with Folium**

# %% [markdown]
# Estimated time needed: **40** minutes

# %% [markdown]
# The launch success rate may depend on many factors such as payload mass, orbit type, and so on. It may also depend on the location and proximities of a launch site, i.e., the initial position of rocket trajectories. Finding an optimal location for building a launch site certainly involves many factors and hopefully we could discover some of the factors by analyzing the existing launch site locations.

# %% [markdown]
# In the previous exploratory data analysis labs, you have visualized the SpaceX launch dataset using `matplotlib` and `seaborn` and discovered some preliminary correlations between the launch site and success rates. In this lab, you will be performing more interactive visual analytics using `Folium`.

# %% [markdown]
# ## Objectives

# %% [markdown]
# This lab contains the following tasks:
# - **TASK 1:** Mark all launch sites on a map
# - **TASK 2:** Mark the success/failed launches for each site on the map
# - **TASK 3:** Calculate the distances between a launch site to its proximities
#
# After completed the above tasks, you should be able to find some geographical patterns about launch sites.

# %% [markdown]
# Let's first import required Python packages for this lab:

# %%
# !pip3 install folium
# !pip3 install wget
# Out:
# Requirement already satisfied: folium in c:\users\master\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: requests in c:\users\master\anaconda3\lib\site-packages (from folium) (2.28.1)
# Requirement already satisfied: branca>=0.6.0 in c:\users\master\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: numpy in c:\users\master\anaconda3\lib\site-packages (from folium) (1.23.5)
# Requirement already satisfied: jinja2>=2.9 in c:\users\master\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\master\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\master\anaconda3\lib\site-packages (from requests->folium) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\master\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\master\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\master\anaconda3\lib\site-packages (from requests->folium) (1.26.14)
# Requirement already satisfied: wget in c:\users\master\anaconda3\lib\site-packages (3.2)

# %%
import folium
import wget
import pandas as pd

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %% [markdown]
# If you need to refresh your memory about folium, you may download and refer to this previous folium lab:

# %% [markdown]
# [Generating Maps with Python](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/DV0101EN-3-5-1-Generating-Maps-in-Python-py-v2.0.ipynb)

# %% [markdown]
# ## Task 1: Mark all launch sites on a map

# %% [markdown]
# First, let's try to add each site's location on a map using site's latitude and longitude coordinates

# %% [markdown]
# The following dataset with the name `spacex_launch_geo.csv` is an augmented dataset with latitude and longitude added for each site.

# %%
# Download and read the `spacex_launch_geo.csv`
spacex_csv_file = wget.download('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv')
spacex_df=pd.read_csv(spacex_csv_file)
# Out:
# 100% [................................................................................] 7710 / 7710

# %% [markdown]
# Now, you can take a look at what are the coordinates for each site.

# %%
# Select relevant sub-columns: `Launch Site`, `Lat(Latitude)`, `Long(Longitude)`, `class`
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# Above coordinates are just plain numbers that can not give you any intuitive insights about where are those launch sites. If you are very good at geography, you can interpret those numbers directly in your mind. If not, that's fine too. Let's visualize those locations by pinning them on a map.

# %% [markdown]
# We first need to create a folium `Map` object, with an initial center location to be NASA Johnson Space Center at Houston, Texas.

# %%
# Start location is NASA Johnson Space Center
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %% [markdown]
# We could use `folium.Circle` to add a highlighted circle area with a text label on a specific coordinate. For example,

# %%
# Create a blue circle at NASA Johnson Space Center's coordinate with a popup label showing its name
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d53680c641232618973b4d650d2793a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d53680c641232618973b4d650d2793a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d53680c641232618973b4d650d2793a = L.map(
#                 &quot;map_8d53680c641232618973b4d650d2793a&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5fd7bca7a968b0330bd37b7dadebca6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d53680c641232618973b4d650d2793a);
#
#
#             var circle_59c0618aaae244691e388cccf278e17c = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8d53680c641232618973b4d650d2793a);
#
#
#         var popup_6c2b9b499b13761a1e9715d581d57340 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c022063145a680d9a8ef1296a90d0902 = $(`&lt;div id=&quot;html_c022063145a680d9a8ef1296a90d0902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_6c2b9b499b13761a1e9715d581d57340.setContent(html_c022063145a680d9a8ef1296a90d0902);
#
#
#
#         circle_59c0618aaae244691e388cccf278e17c.bindPopup(popup_6c2b9b499b13761a1e9715d581d57340)
#         ;
#
#
#
#
#             var marker_168d9fe369ef28f6576505bdae787317 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_8d53680c641232618973b4d650d2793a);
#
#
#             var div_icon_513a2e2e187dd11cb1ae96b54310eea7 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_168d9fe369ef28f6576505bdae787317.setIcon(div_icon_513a2e2e187dd11cb1ae96b54310eea7);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# and you should find a small yellow circle near the city of Houston and you can zoom-in to see a larger circle.

# %% [markdown]
# Now, let's add a circle for each launch site in data frame `launch_sites`

# %% [markdown]
# _TODO:_  Create and add `folium.Circle` and `folium.Marker` for each launch site on the site map

# %% [markdown]
# An example of folium.Circle:

# %% [markdown]
# `folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(...))`

# %% [markdown]
# An example of folium.Marker:

# %% [markdown]
# `folium.map.Marker(coordinate, icon=DivIcon(icon_size=(20,20),icon_anchor=(0,0), html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'label', ))`

# %%
# Initial the map
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)
# For each launch site, add a Circle object based on its coordinate (Lat, Long) values. In addition, add Launch site name as a popup label

ls_name = launch_sites_df['Launch Site']
for _, i in launch_sites_df.iterrows():
    coords = [i['Lat'], i['Long']]
    ls_name = i['Launch Site']
    circle = folium.Circle(location = coords, radius=1000, color='#d35400', fill=True).add_child(folium.Popup(ls_name))
    marker = folium.Marker(location = coords,
               radius=1000, color='#d35400', fill=True,
            icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % ls_name,
        )
                          ).add_child(folium.Popup(ls_name))
    site_map.add_child(circle)
    site_map.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a67c71a0efd0be6ec78efbc95a052c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a67c71a0efd0be6ec78efbc95a052c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5a67c71a0efd0be6ec78efbc95a052c8 = L.map(
#                 &quot;map_5a67c71a0efd0be6ec78efbc95a052c8&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a90c9795c947e11f764b4818267414eb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5a67c71a0efd0be6ec78efbc95a052c8);
#
#
#             var circle_3d5fa8662790a70d3c6f216c3309ae73 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a67c71a0efd0be6ec78efbc95a052c8);
#
#
#         var popup_4918b028f7324822251c52ffbd12c177 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4363360f20ca4b316298f09315ac1319 = $(`&lt;div id=&quot;html_4363360f20ca4b316298f09315ac1319&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_4918b028f7324822251c52ffbd12c177.setContent(html_4363360f20ca4b316298f09315ac1319);
#
#
#
#         circle_3d5fa8662790a70d3c6f216c3309ae73.bindPopup(popup_4918b028f7324822251c52ffbd12c177)
#         ;
#
#
#
#
#             var marker_e29e1c181df2333a5f2bb6b8ae960d95 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_5a67c71a0efd0be6ec78efbc95a052c8);
#
#
#             var div_icon_b8aec06880620fa0620f75284d73742a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_e29e1c181df2333a5f2bb6b8ae960d95.setIcon(div_icon_b8aec06880620fa0620f75284d73742a);
#
#
#         var popup_e2bf9d6080f3ffe7a25cef7bdad80798 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1407ebc2ba9e08e208305f84a6a2c372 = $(`&lt;div id=&quot;html_1407ebc2ba9e08e208305f84a6a2c372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_e2bf9d6080f3ffe7a25cef7bdad80798.setContent(html_1407ebc2ba9e08e208305f84a6a2c372);
#
#
#
#         marker_e29e1c181df2333a5f2bb6b8ae960d95.bindPopup(popup_e2bf9d6080f3ffe7a25cef7bdad80798)
#         ;
#
#
#
#
#             var circle_f3d33f3716c44b401b83925bc38eef09 = L.circle(
#                 [28.56319718, -80.57682003],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a67c71a0efd0be6ec78efbc95a052c8);
#
#
#         var popup_1bc21cac0c296dc7a6a6a957e32c64db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1641b862ccea35f093ac0234836087fc = $(`&lt;div id=&quot;html_1641b862ccea35f093ac0234836087fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS SLC-40&lt;/div&gt;`)[0];
#                 popup_1bc21cac0c296dc7a6a6a957e32c64db.setContent(html_1641b862ccea35f093ac0234836087fc);
#
#
#
#         circle_f3d33f3716c44b401b83925bc38eef09.bindPopup(popup_1bc21cac0c296dc7a6a6a957e32c64db)
#         ;
#
#
#
#
#             var marker_35f5b90d7f67d71aaafc5c9401a5ec71 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}

# %% [markdown]
# The generated map with marked launch sites should look similar to the following:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_markers.png">
# </center>

# %% [markdown]
# Now, you can explore the map by zoom-in/out the marked areas
# , and try to answer the following questions:
# - Are all launch sites in proximity to the Equator line?
# - Are all launch sites in very close proximity to the coast?
#
# Also please try to explain your findings.

# %% [markdown]
# # Task 2: Mark the success/failed launches for each site on the map

# %% [markdown]
# Next, let's try to enhance the map by adding the launch outcomes for each site, and see which sites have high success rates.
# Recall that data frame spacex_df has detailed launch records, and the `class` column indicates if this launch was successful or not

# %%
spacex_df.tail(10)
# Out:
#      Launch Site        Lat       Long  class
# 46    KSC LC-39A  28.573255 -80.646895      1
# 47    KSC LC-39A  28.573255 -80.646895      1
# 48    KSC LC-39A  28.573255 -80.646895      1
# 49  CCAFS SLC-40  28.563197 -80.576820      1
# 50  CCAFS SLC-40  28.563197 -80.576820      1
# 51  CCAFS SLC-40  28.563197 -80.576820      0
# 52  CCAFS SLC-40  28.563197 -80.576820      0
# 53  CCAFS SLC-40  28.563197 -80.576820      0
# 54  CCAFS SLC-40  28.563197 -80.576820      1
# 55  CCAFS SLC-40  28.563197 -80.576820      0

# %% [markdown]
# Next, let's create markers for all launch records.
# If a launch was successful `(class=1)`, then we use a green marker and if a launch was failed, we use a red marker `(class=0)`

# %% [markdown]
# Note that a launch only happens in one of the four launch sites, which means many launch records will have the exact same coordinate. Marker clusters can be a good way to simplify a map containing many markers having the same coordinate.

# %% [markdown]
# Let's first create a `MarkerCluster` object

# %%
marker_cluster = MarkerCluster()

# %%
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %% [markdown]
# _TODO:_ Create a new column in `launch_sites` dataframe called `marker_color` to store the marker colors based on the `class` value

# %%
# Apply a function to check the value of `class` column
# If class=1, marker_color value will be green
# If class=0, marker_color value will be red
def f(launch_outcome):
    if launch_outcome == 1:
        return 'green'
    else:
        return 'red'
    
spacex_df['marker_color'] = spacex_df['class'].apply(f)
spacex_df.tail()
# Out:
#      Launch Site        Lat      Long  class marker_color
# 51  CCAFS SLC-40  28.563197 -80.57682      0          red
# 52  CCAFS SLC-40  28.563197 -80.57682      0          red
# 53  CCAFS SLC-40  28.563197 -80.57682      0          red
# 54  CCAFS SLC-40  28.563197 -80.57682      1        green
# 55  CCAFS SLC-40  28.563197 -80.57682      0          red

# %% [markdown]
# _TODO:_ For each launch result in `spacex_df` data frame, add a `folium.Marker` to `marker_cluster`

# %%
# Add marker_cluster to current site_map
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for _, row in spacex_df.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    marker = folium.Marker(location = [row["Lat"], row["Long"]]
                           ,icon=folium.Icon(color=row['marker_color'], icon_color=row['marker_color'],
                                            popup=row['class']))

    # Create an icon as a text label
    # marker = folium.Marker(...)
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8fece5f35ca1712446c0cb6f9655c55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8fece5f35ca1712446c0cb6f9655c55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8fece5f35ca1712446c0cb6f9655c55 = L.map(
#                 &quot;map_c8fece5f35ca1712446c0cb6f9655c55&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa72d0c9ed5aec3e7bb0b89a3d9b3790 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c8fece5f35ca1712446c0cb6f9655c55);
#
#
#             var marker_ef1c8d1db7f1e99f7ecd9708cf982a4b = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_c8fece5f35ca1712446c0cb6f9655c55);
#
#
#         var popup_61473782270e936c5d6c81a3f02dc17f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f4188db6905fe312da4d5abbfe53c1f3 = $(`&lt;div id=&quot;html_f4188db6905fe312da4d5abbfe53c1f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_61473782270e936c5d6c81a3f02dc17f.setContent(html_f4188db6905fe312da4d5abbfe53c1f3);
#
#
#
#         marker_ef1c8d1db7f1e99f7ecd9708cf982a4b.bindPopup(popup_61473782270e936c5d6c81a3f02dc17f)
#         ;
#
#
#
#
#             var marker_51d3358d1649a8834212d21f5d1417ff = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_c8fece5f35ca1712446c0cb6f9655c55);
#
#
#         var popup_c2558969f41ad6d447bca553d258ca12 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ed450b8a3d09af08ee8447e89c7a877 = $(`&lt;div id=&quot;html_1ed450b8a3d09af08ee8447e89c7a877&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_c2558969f41ad6d447bca553d258ca12.setContent(html_1ed450b8a3d09af08ee8447e89c7a877);
#
#
#
#         marker_51d3358d1649a8834212d21f5d1417ff.bindPopup(popup_c2558969f41ad6d447bca553d258ca12)
#         ;
#
#
#
#
#             var marker_2f8c9b1f1e7cecc8ca7c00765521d230 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_c8fece5f35ca1712446c0cb6f9655c55);
#
#
#         var popup_0262ef39f6ca375a36e49c2b258d8d9f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6cddf989bb3b6a75904090336383e7fe = $(`&lt;div id=&quot;html_6cddf989bb3b6a75904090336383e7fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_0262ef39f6ca375a36e49c2b258d8d9f.setContent(html_6cddf989bb3b6a75904090336383e7fe);
#
#
#
#         marker_2f8c9b1f1e7cecc8ca7c00765521d230.bindPopup(popup_0262ef39f6ca375a36e49c2b258d8d9f)
#         ;
#
#
#
#
#             var marker_57649d7f44abef4ea9fee7c06c713c60 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_c8fece5f35ca1712446c0cb6f9655c55);
#
#
#         var popup_3a4a6f16fba8083e99490b925b5dc37e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2aefffea3e426e3ea28506f1dedee50 = $(`&lt;div id=&quot;html_c2aefffea3e426e3ea28506f1dedee50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_3a4a6f16fba8083e99490b925b5dc37e.setContent(html_c2aefffea3e426e3ea28506f1dedee50);
#
#
#
#         marker_57649d7f44abef4ea9fee7c06c713c60.bindPopup(popup_3a4a6f16fba8083e99490b925b5dc37e)
#         ;
#
#
#
#
#             var marker_27e7a7bea1d907568a9113ea7f66c2bf = L.marker(
#                 [28.

# %% [markdown]
# Your updated map may look like the following screenshots:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster.png">
# </center>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_cluster_zoomed.png">
# </center>

# %% [markdown]
# From the color-labeled markers in marker clusters, you should be able to easily identify which launch sites have relatively high success rates.

# %% [markdown]
# # TASK 3: Calculate the distances between a launch site to its proximities

# %% [markdown]
# Next, we need to explore and analyze the proximities of launch sites.

# %% [markdown]
# Let's first add a `MousePosition` on the map to get coordinate for a mouse over a point on the map. As such, while you are exploring the map, you can easily find the coordinates of any points of interests (such as railway)

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffe7107cf007b1715dac40be5d836aad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffe7107cf007b1715dac40be5d836aad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffe7107cf007b1715dac40be5d836aad = L.map(
#                 &quot;map_ffe7107cf007b1715dac40be5d836aad&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcbb389f4b554c50a4ed7e4e3ddd1aca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ffe7107cf007b1715dac40be5d836aad);
#
#
#             var marker_90d465ceaf8a1af10306023d57af35cb = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003elabel\u003c/b\u003e\u003c/div\u003e&quot;, &quot;radius&quot;: 1000}
#             ).addTo(map_ffe7107cf007b1715dac40be5d836aad);
#
#
#         var popup_5ffe0cc95e78d4d7322fe182dada0bfa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f59ec808daf1eca330d6e7bbfd793af = $(`&lt;div id=&quot;html_6f59ec808daf1eca330d6e7bbfd793af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_5ffe0cc95e78d4d7322fe182dada0bfa.setContent(html_6f59ec808daf1eca330d6e7bbfd793af);
#
#
#
#         marker_90d465ceaf8a1af10306023d57af35cb.bindPopup(popup_5ffe0cc95e78d4d7322fe182dada0bfa)
#         ;
#
#
#
#
#             var marker_2d029b0fc40809a43e393b4351cac405 = L.marker(
#                 [28.56319718, -80.57682003],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003elabel\u003c/b\u003e\u003c/div\u003e&quot;, &quot;radius&quot;: 1000}
#             ).addTo(map_ffe7107cf007b1715dac40be5d836aad);
#
#
#         var popup_332770e5d9b65a23081804a8598e46a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_945068ef1832c69aee35087f2335e169 = $(`&lt;div id=&quot;html_945068ef1832c69aee35087f2335e169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_332770e5d9b65a23081804a8598e46a3.setContent(html_945068ef1832c69aee35087f2335e169);
#
#
#
#         marker_2d029b0fc40809a43e393b4351cac405.bindPopup(popup_332770e5d9b65a23081804a8598e46a3)
#         ;
#
#
#
#
#             var marker_c93a634f72c0831bfe140f6558b58f15 = L.marker(
#                 [28.57325457, -80.64689529],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003elabel\u003c/b\u003e\u003c/div\u003e&quot;, &quot;radius&quot;: 1000}
#             ).addTo(map_ffe7107cf007b1715dac40be5d836aad);
#
#
#         var popup_ae8bc917abae1d668ab29473495a912e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b307dd651766a2bd2095d452903566d = $(`&lt;div id=&quot;html_6b307dd651766a2bd2095d452903566d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_ae8bc917abae1d668ab29473495a912e.setContent(html_6b307dd651766a2bd2095d452903566d);
#
#
#
#         marker_c93a634f72c0831bfe140f6558b58f15.bindPopup(popup_ae8bc917abae1d668ab29473495a912e)
#         ;
#
#
#
#
#             var marker_0a0738443d6af83c24d2ae63aa179793 = L.marker(
#                 [34.63283416, -120.6107455],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;html&quot;: &quot;\u003cdiv style=\&quot;f

# %% [markdown]
# Now zoom in to a launch site and explore its proximity to see if you can easily find any railway, highway, coastline, etc. Move your mouse to these points and mark down their coordinates (shown on the top-left) in order to the distance to the launch site.

# %% [markdown]
# You can calculate the distance between two points on the map based on their `Lat` and `Long` values using the following method:

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %% [markdown]
# _TODO:_ Mark down a point on the closest coastline using MousePosition and calculate the distance between the coastline point and the launch site.

# %%
# find coordinate of the closet coastline
# e.g.,: Lat: 28.56367  Lon: -80.57163
# distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)
launch_site_lat, launch_site_lon = 28.56323, -80.57681
coastline_lat, coastline_lon = 28.56324, -80.56798
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, coastline_lat, coastline_lon)
distance_coastline
# Out:
# 0.8626214782026091

# %%
# Create and add a folium.Marker on your selected closest coastline point on the map
# Display the distance between coastline point and launch site using the icon property 
# for example
# distance_marker = folium.Marker(
#    coordinate,
#    icon=DivIcon(
#        icon_size=(20,20),
#        icon_anchor=(0,0),
#        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
#        )
#    )

distance_marker = folium.Marker(
    location=[coastline_lat, coastline_lon],
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
        )
    )

site_map.add_child(distance_marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8986ba646d8263203f2d0765bf4af633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8986ba646d8263203f2d0765bf4af633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8986ba646d8263203f2d0765bf4af633 = L.map(
#                 &quot;map_8986ba646d8263203f2d0765bf4af633&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7d3c752dd9a1b1b09285d38e058aa21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#             var marker_c6369f5e5c3c2cbae9f653a1b63a03e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_edc9679586d184e6ccb330d7e467a5d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b36f971385860591eb40a648ea81c45c = $(`&lt;div id=&quot;html_b36f971385860591eb40a648ea81c45c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_edc9679586d184e6ccb330d7e467a5d8.setContent(html_b36f971385860591eb40a648ea81c45c);
#
#
#
#         marker_c6369f5e5c3c2cbae9f653a1b63a03e2.bindPopup(popup_edc9679586d184e6ccb330d7e467a5d8)
#         ;
#
#
#
#
#             var marker_24d73fb3cbf6be9f4c2fff93b7aaaa20 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f9d6bd3a8c5f5fcc53cb829275fb63c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a02453bbc67b8c9eac898232340fecd = $(`&lt;div id=&quot;html_2a02453bbc67b8c9eac898232340fecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_f9d6bd3a8c5f5fcc53cb829275fb63c9.setContent(html_2a02453bbc67b8c9eac898232340fecd);
#
#
#
#         marker_24d73fb3cbf6be9f4c2fff93b7aaaa20.bindPopup(popup_f9d6bd3a8c5f5fcc53cb829275fb63c9)
#         ;
#
#
#
#
#             var marker_3f67ec58f87fdfe4df43c197e816c8e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_c1bcc39cfa93cf663a869ba80c2da48f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4433b9423a61cff68f3db88d736c3289 = $(`&lt;div id=&quot;html_4433b9423a61cff68f3db88d736c3289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_c1bcc39cfa93cf663a869ba80c2da48f.setContent(html_4433b9423a61cff68f3db88d736c3289);
#
#
#
#         marker_3f67ec58f87fdfe4df43c197e816c8e2.bindPopup(popup_c1bcc39cfa93cf663a869ba80c2da48f)
#         ;
#
#
#
#
#             var marker_657f005bf445269bf99f70feb760aee7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_aee34e8984d6e4a1f88e69835712994e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4352cea5d3b900fcb5781042fe060a13 = $(`&lt;div id=&quot;html_4352cea5d3b900fcb5781042fe060a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_aee34e8984d6e4a1f88e69835712994e.setContent(html_4352cea5d3b900fcb5781042fe060a13);
#
#
#
#         marker_657f005bf445269bf99f70feb760aee7.bindPopup(popup_aee34e8984d6e4a1f88e69835712994e)
#         ;
#
#
#
#
#             var marker_5db25304039cd55d7060702a44c4ce48 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f2453ea2b56c58ae4e551d80d10bb5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21e7727b05084ec6642c9275364cd9c2 = $(`&lt;div id=&quot;html_21e7727b05084ec6642c9275364

# %% [markdown]
# _TODO:_ Draw a `PolyLine` between a launch site to the selected coastline point

# %%
# Create a `folium.PolyLine` object using the coastline coordinates and launch site coordinate
# lines=folium.PolyLine(locations=coordinates, weight=1)
lines=folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [coastline_lat, coastline_lon]], weight=1)
site_map.add_child(lines)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8986ba646d8263203f2d0765bf4af633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8986ba646d8263203f2d0765bf4af633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8986ba646d8263203f2d0765bf4af633 = L.map(
#                 &quot;map_8986ba646d8263203f2d0765bf4af633&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7d3c752dd9a1b1b09285d38e058aa21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#             var marker_c6369f5e5c3c2cbae9f653a1b63a03e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_edc9679586d184e6ccb330d7e467a5d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b36f971385860591eb40a648ea81c45c = $(`&lt;div id=&quot;html_b36f971385860591eb40a648ea81c45c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_edc9679586d184e6ccb330d7e467a5d8.setContent(html_b36f971385860591eb40a648ea81c45c);
#
#
#
#         marker_c6369f5e5c3c2cbae9f653a1b63a03e2.bindPopup(popup_edc9679586d184e6ccb330d7e467a5d8)
#         ;
#
#
#
#
#             var marker_24d73fb3cbf6be9f4c2fff93b7aaaa20 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f9d6bd3a8c5f5fcc53cb829275fb63c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a02453bbc67b8c9eac898232340fecd = $(`&lt;div id=&quot;html_2a02453bbc67b8c9eac898232340fecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_f9d6bd3a8c5f5fcc53cb829275fb63c9.setContent(html_2a02453bbc67b8c9eac898232340fecd);
#
#
#
#         marker_24d73fb3cbf6be9f4c2fff93b7aaaa20.bindPopup(popup_f9d6bd3a8c5f5fcc53cb829275fb63c9)
#         ;
#
#
#
#
#             var marker_3f67ec58f87fdfe4df43c197e816c8e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_c1bcc39cfa93cf663a869ba80c2da48f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4433b9423a61cff68f3db88d736c3289 = $(`&lt;div id=&quot;html_4433b9423a61cff68f3db88d736c3289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_c1bcc39cfa93cf663a869ba80c2da48f.setContent(html_4433b9423a61cff68f3db88d736c3289);
#
#
#
#         marker_3f67ec58f87fdfe4df43c197e816c8e2.bindPopup(popup_c1bcc39cfa93cf663a869ba80c2da48f)
#         ;
#
#
#
#
#             var marker_657f005bf445269bf99f70feb760aee7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_aee34e8984d6e4a1f88e69835712994e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4352cea5d3b900fcb5781042fe060a13 = $(`&lt;div id=&quot;html_4352cea5d3b900fcb5781042fe060a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_aee34e8984d6e4a1f88e69835712994e.setContent(html_4352cea5d3b900fcb5781042fe060a13);
#
#
#
#         marker_657f005bf445269bf99f70feb760aee7.bindPopup(popup_aee34e8984d6e4a1f88e69835712994e)
#         ;
#
#
#
#
#             var marker_5db25304039cd55d7060702a44c4ce48 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f2453ea2b56c58ae4e551d80d10bb5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21e7727b05084ec6642c9275364cd9c2 = $(`&lt;div id=&quot;html_21e7727b05084ec6642c9275364

# %% [markdown]
# Your updated map with distance line should look like the following screenshot:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/launch_site_marker_distance.png">
# </center>

# %% [markdown]
# _TODO:_ Similarly, you can draw a line betwee a launch site to its closest city, railway, highway, etc. You need to use `MousePosition` to find the their coordinates on the map first

# %% [markdown]
# A railway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/railway.png">
# </center>

# %% [markdown]
# A highway map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/highway.png">
# </center>

# %% [markdown]
# A city map symbol may look like this:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_3/images/city.png">
# </center>

# %%
# Create a marker with distance to a closest city, railway, highway, etc.
# Draw a line between the marker to the launch site

# %%
# railway

launch_site_lat, launch_site_lon = 28.56323, -80.57681
railway_lat, railway_lon = 28.55784, -80.80101
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, railway_lat, railway_lon)
distance_coastline


distance_marker = folium.Marker(
    location=[railway_lat, railway_lon],
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
        )
    )

site_map.add_child(distance_marker)
site_map

lines=folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [railway_lat, railway_lon]], weight=1)
site_map.add_child(lines)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8986ba646d8263203f2d0765bf4af633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8986ba646d8263203f2d0765bf4af633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8986ba646d8263203f2d0765bf4af633 = L.map(
#                 &quot;map_8986ba646d8263203f2d0765bf4af633&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7d3c752dd9a1b1b09285d38e058aa21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#             var marker_c6369f5e5c3c2cbae9f653a1b63a03e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_edc9679586d184e6ccb330d7e467a5d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b36f971385860591eb40a648ea81c45c = $(`&lt;div id=&quot;html_b36f971385860591eb40a648ea81c45c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_edc9679586d184e6ccb330d7e467a5d8.setContent(html_b36f971385860591eb40a648ea81c45c);
#
#
#
#         marker_c6369f5e5c3c2cbae9f653a1b63a03e2.bindPopup(popup_edc9679586d184e6ccb330d7e467a5d8)
#         ;
#
#
#
#
#             var marker_24d73fb3cbf6be9f4c2fff93b7aaaa20 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f9d6bd3a8c5f5fcc53cb829275fb63c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a02453bbc67b8c9eac898232340fecd = $(`&lt;div id=&quot;html_2a02453bbc67b8c9eac898232340fecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_f9d6bd3a8c5f5fcc53cb829275fb63c9.setContent(html_2a02453bbc67b8c9eac898232340fecd);
#
#
#
#         marker_24d73fb3cbf6be9f4c2fff93b7aaaa20.bindPopup(popup_f9d6bd3a8c5f5fcc53cb829275fb63c9)
#         ;
#
#
#
#
#             var marker_3f67ec58f87fdfe4df43c197e816c8e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_c1bcc39cfa93cf663a869ba80c2da48f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4433b9423a61cff68f3db88d736c3289 = $(`&lt;div id=&quot;html_4433b9423a61cff68f3db88d736c3289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_c1bcc39cfa93cf663a869ba80c2da48f.setContent(html_4433b9423a61cff68f3db88d736c3289);
#
#
#
#         marker_3f67ec58f87fdfe4df43c197e816c8e2.bindPopup(popup_c1bcc39cfa93cf663a869ba80c2da48f)
#         ;
#
#
#
#
#             var marker_657f005bf445269bf99f70feb760aee7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_aee34e8984d6e4a1f88e69835712994e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4352cea5d3b900fcb5781042fe060a13 = $(`&lt;div id=&quot;html_4352cea5d3b900fcb5781042fe060a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_aee34e8984d6e4a1f88e69835712994e.setContent(html_4352cea5d3b900fcb5781042fe060a13);
#
#
#
#         marker_657f005bf445269bf99f70feb760aee7.bindPopup(popup_aee34e8984d6e4a1f88e69835712994e)
#         ;
#
#
#
#
#             var marker_5db25304039cd55d7060702a44c4ce48 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f2453ea2b56c58ae4e551d80d10bb5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21e7727b05084ec6642c9275364cd9c2 = $(`&lt;div id=&quot;html_21e7727b05084ec6642c9275364

# %%
# highway

launch_site_lat, launch_site_lon = 28.56323, -80.57681
highway_lat, highway_lon = 28.55101, -80.85182
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, highway_lat, highway_lon)
distance_coastline


distance_marker = folium.Marker(
    location=[highway_lat, highway_lon],
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
        )
    )

site_map.add_child(distance_marker)
site_map

lines=folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [highway_lat, highway_lon]], weight=1)
site_map.add_child(lines)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8986ba646d8263203f2d0765bf4af633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8986ba646d8263203f2d0765bf4af633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8986ba646d8263203f2d0765bf4af633 = L.map(
#                 &quot;map_8986ba646d8263203f2d0765bf4af633&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7d3c752dd9a1b1b09285d38e058aa21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#             var marker_c6369f5e5c3c2cbae9f653a1b63a03e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_edc9679586d184e6ccb330d7e467a5d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b36f971385860591eb40a648ea81c45c = $(`&lt;div id=&quot;html_b36f971385860591eb40a648ea81c45c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_edc9679586d184e6ccb330d7e467a5d8.setContent(html_b36f971385860591eb40a648ea81c45c);
#
#
#
#         marker_c6369f5e5c3c2cbae9f653a1b63a03e2.bindPopup(popup_edc9679586d184e6ccb330d7e467a5d8)
#         ;
#
#
#
#
#             var marker_24d73fb3cbf6be9f4c2fff93b7aaaa20 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f9d6bd3a8c5f5fcc53cb829275fb63c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a02453bbc67b8c9eac898232340fecd = $(`&lt;div id=&quot;html_2a02453bbc67b8c9eac898232340fecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_f9d6bd3a8c5f5fcc53cb829275fb63c9.setContent(html_2a02453bbc67b8c9eac898232340fecd);
#
#
#
#         marker_24d73fb3cbf6be9f4c2fff93b7aaaa20.bindPopup(popup_f9d6bd3a8c5f5fcc53cb829275fb63c9)
#         ;
#
#
#
#
#             var marker_3f67ec58f87fdfe4df43c197e816c8e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_c1bcc39cfa93cf663a869ba80c2da48f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4433b9423a61cff68f3db88d736c3289 = $(`&lt;div id=&quot;html_4433b9423a61cff68f3db88d736c3289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_c1bcc39cfa93cf663a869ba80c2da48f.setContent(html_4433b9423a61cff68f3db88d736c3289);
#
#
#
#         marker_3f67ec58f87fdfe4df43c197e816c8e2.bindPopup(popup_c1bcc39cfa93cf663a869ba80c2da48f)
#         ;
#
#
#
#
#             var marker_657f005bf445269bf99f70feb760aee7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_aee34e8984d6e4a1f88e69835712994e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4352cea5d3b900fcb5781042fe060a13 = $(`&lt;div id=&quot;html_4352cea5d3b900fcb5781042fe060a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_aee34e8984d6e4a1f88e69835712994e.setContent(html_4352cea5d3b900fcb5781042fe060a13);
#
#
#
#         marker_657f005bf445269bf99f70feb760aee7.bindPopup(popup_aee34e8984d6e4a1f88e69835712994e)
#         ;
#
#
#
#
#             var marker_5db25304039cd55d7060702a44c4ce48 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f2453ea2b56c58ae4e551d80d10bb5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21e7727b05084ec6642c9275364cd9c2 = $(`&lt;div id=&quot;html_21e7727b05084ec6642c9275364

# %%
# city

launch_site_lat, launch_site_lon = 28.56323, -80.57681
orlando_lat, orlando_lon = 28.53244, -81.39221
distance_coastline = calculate_distance(launch_site_lat, launch_site_lon, orlando_lat, orlando_lon)
distance_coastline


distance_marker = folium.Marker(
    location=[orlando_lat, orlando_lon],
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance_coastline),
        )
    )

site_map.add_child(distance_marker)
site_map

lines=folium.PolyLine(locations=[[launch_site_lat, launch_site_lon], [orlando_lat, orlando_lon]], weight=1)
site_map.add_child(lines)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8986ba646d8263203f2d0765bf4af633 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8986ba646d8263203f2d0765bf4af633&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8986ba646d8263203f2d0765bf4af633 = L.map(
#                 &quot;map_8986ba646d8263203f2d0765bf4af633&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d7d3c752dd9a1b1b09285d38e058aa21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#             var marker_c6369f5e5c3c2cbae9f653a1b63a03e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_edc9679586d184e6ccb330d7e467a5d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b36f971385860591eb40a648ea81c45c = $(`&lt;div id=&quot;html_b36f971385860591eb40a648ea81c45c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_edc9679586d184e6ccb330d7e467a5d8.setContent(html_b36f971385860591eb40a648ea81c45c);
#
#
#
#         marker_c6369f5e5c3c2cbae9f653a1b63a03e2.bindPopup(popup_edc9679586d184e6ccb330d7e467a5d8)
#         ;
#
#
#
#
#             var marker_24d73fb3cbf6be9f4c2fff93b7aaaa20 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f9d6bd3a8c5f5fcc53cb829275fb63c9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a02453bbc67b8c9eac898232340fecd = $(`&lt;div id=&quot;html_2a02453bbc67b8c9eac898232340fecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_f9d6bd3a8c5f5fcc53cb829275fb63c9.setContent(html_2a02453bbc67b8c9eac898232340fecd);
#
#
#
#         marker_24d73fb3cbf6be9f4c2fff93b7aaaa20.bindPopup(popup_f9d6bd3a8c5f5fcc53cb829275fb63c9)
#         ;
#
#
#
#
#             var marker_3f67ec58f87fdfe4df43c197e816c8e2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_c1bcc39cfa93cf663a869ba80c2da48f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4433b9423a61cff68f3db88d736c3289 = $(`&lt;div id=&quot;html_4433b9423a61cff68f3db88d736c3289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_c1bcc39cfa93cf663a869ba80c2da48f.setContent(html_4433b9423a61cff68f3db88d736c3289);
#
#
#
#         marker_3f67ec58f87fdfe4df43c197e816c8e2.bindPopup(popup_c1bcc39cfa93cf663a869ba80c2da48f)
#         ;
#
#
#
#
#             var marker_657f005bf445269bf99f70feb760aee7 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_aee34e8984d6e4a1f88e69835712994e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4352cea5d3b900fcb5781042fe060a13 = $(`&lt;div id=&quot;html_4352cea5d3b900fcb5781042fe060a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Launch Sites&lt;/div&gt;`)[0];
#                 popup_aee34e8984d6e4a1f88e69835712994e.setContent(html_4352cea5d3b900fcb5781042fe060a13);
#
#
#
#         marker_657f005bf445269bf99f70feb760aee7.bindPopup(popup_aee34e8984d6e4a1f88e69835712994e)
#         ;
#
#
#
#
#             var marker_5db25304039cd55d7060702a44c4ce48 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {&quot;color&quot;: &quot;#d35400&quot;, &quot;fill&quot;: true, &quot;radius&quot;: 1000}
#             ).addTo(map_8986ba646d8263203f2d0765bf4af633);
#
#
#         var popup_f2453ea2b56c58ae4e551d80d10bb5c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21e7727b05084ec6642c9275364cd9c2 = $(`&lt;div id=&quot;html_21e7727b05084ec6642c9275364

# %% [markdown]
# After you plot distance lines to the proximities, you can answer the following questions easily:
# - Are launch sites in close proximity to railways?
# - Are launch sites in close proximity to highways?
# - Are launch sites in close proximity to coastline?
# - Do launch sites keep certain distance away from cities?
#
# Also please try to explain your findings.

# %% [markdown]
# # Next Steps:
#
# Now you have discovered many interesting insights related to the launch sites' location using folium, in a very interactive way. Next, you will need to build a dashboard using Ploty Dash on detailed launch records.

# %% [markdown]
# ## Authors

# %% [markdown]
# [Yan Luo](https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Joseph Santarcangelo

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2021-05-26|1.0|Yan|Created the initial version|

# %% [markdown]
# Copyright © 2021 IBM Corporation. All rights reserved.
